# %% [markdown]
# # Heart Disease Risk Prediction
#
# Decision Tree pipeline for predicting heart disease risk levels (low, moderate, high) using the UCI heart disease dataset variants available in this repository.
